# %%
# SH-I

# %%
import pandas as pd
import numpy as np

# %%
rfu_norm = pd.read_csv('rfu_norm.csv')
tar = pd.read_csv('tar.csv')

rfu_norm.set_index('Structure on Masterlist', inplace = True)

# %%
rfu_norm.columns = tar['Target Name'].values

# %%
rfu_norm
# Out:
#                                                     A/OK/5386 (1:30Dilution)  \
# Structure on Masterlist
# Gala-Sp8                                                            0.100846
# Glca-Sp8                                                            0.115088
# Mana-Sp8                                                            0.237031
# GalNAca-Sp8                                                         0.098039
# GalNAca-Sp15                                                        0.095650
# Fuca-Sp8                                                            0.093260
# Fuca-Sp9                                                            0.098549
# Rhaa-Sp8                                                            0.095406
# Neu5Aca-Sp8                                                         0.108975
# Neu5Aca-Sp11                                                        0.093645
# Neu5Acb-Sp8                                                         0.084524
# ...

# %%
rfu_norm.to_csv('rfu_norm2.csv')
